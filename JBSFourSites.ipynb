# %%
import pandas as pd
import numpy as np
import glob

# %%
path =r'/Users/AllyEnergy/Downloads/Brian/Brian' 
allFiles = glob.glob(path + "/*.csv")
frame = list()
for file_ in allFiles:
    df = pd.read_csv(file_, skiprows= 21, header=1, usecols= [1, *range(3,18)])  
# To skip rows use "skiprows= [*range(2,12), *range(45,50)]"  
    frame.append(df)   
frameABC = pd.concat(frame, axis = 0)
frameABC
#FrameABCList
#frameABC.to_csv('/Users/AllyEnergy/Downloads/frameOutput5.csv', header = True, index=True )
# Out:
#                                            Site            Account  \
# Electric     PPC108 (PPC WACO GA - GK FEEDMILL)          122902002
# Electric     PPC108 (PPC WACO GA - GK FEEDMILL)          122902002
# Electric     PPC108 (PPC WACO GA - GK FEEDMILL)          122902002
# Electric     PPC108 (PPC WACO GA - GK FEEDMILL)          122902002
# Electric     PPC108 (PPC WACO GA - GK FEEDMILL)          122902002
# Electric         PPC111 (PPC CANTON TRUCK SHOP)         7521137018
# Electric         PPC111 (PPC CANTON TRUCK SHOP)         7521137018
# Electric         PPC111 (PPC CANTON TRUCK SHOP)         7521137018
# Electric         PPC111 (PPC CANTON TRUCK SHOP)         7521137018
# Electric         PPC111 (PPC CANTON TRUCK SHOP)         7521137018
# Electric    PPC121 (PPC NACOGDOCHES TRUCK SHOP)  Multiple Accounts
# Electric    PPC121 (PPC NACOGDOCHES TRUCK SHOP)  Multiple Accounts
# Electric    PPC121 (PPC NACOGDOCHES TRUCK SHOP)  Multiple Accounts
# ...

# %%
frameABC.to_csv('/Users/AllyEnergy/Downloads/Brian/Brian/JBS_Four_Sites_Usage.csv')
